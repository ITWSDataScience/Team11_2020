# %% [markdown]
# ## Final Project

# %% [markdown]
# The NOAA Merged Land Ocean Global Surface Temperature Analysis Dataset (NOAAGlobalTemp) merges two dataset to form one land–ocean surface temperature analysis (formerly known as MLOST).NOAAGlobalTEmp consists of a spatially gridded (5° × 5°) global surface temperature dataset, with monthly resolution from January 1880 to present. We combine a global sea surface (water) temperature (SST) dataset with a global land surface air temperature dataset into this merged dataset of both the Earth’s land and ocean surface temperatures, currently as version v5. The Extended Reconstructed Sea Surface Temperature (ERSST) version 5 provides the foundational SST observations. The land surface air temperature observations come from the Global Historical Climatology Network Monthly (GHCN-Monthly) database, version 4.
#
# #### Some read me from https://www.ncdc.noaa.gov/monitoring-references/faq/anomalies.php
#
# ##### Anomaly
# The term temperature anomaly means a departure from a reference value or long-term average. A positive anomaly indicates that the observed temperature was warmer than the reference value, while a negative anomaly indicates that the observed temperature was cooler than the reference value.
#
# ##### Why?
# Absolute estimates of global average surface temperature are difficult to compile for several reasons. Some regions have few temperature measurement stations (e.g., the Sahara Desert) and interpolation must be made over large, data-sparse regions. In mountainous areas, most observations come from the inhabited valleys, so the effect of elevation on a region's average temperature must be considered as well. For example, a summer month over an area may be cooler than average, both at a mountain top and in a nearby valley, but the absolute temperatures will be quite different at the two locations. The use of anomalies in this case will show that temperatures for both locations were below average.
#
# Using reference values computed on smaller [more local] scales over the same time period establishes a baseline from which anomalies are calculated. This effectively normalizes the data so they can be compared and combined to more accurately represent temperature patterns with respect to what is normal for different places within a region.
#
# For these reasons, large-area summaries incorporate anomalies, not the temperature itself. Anomalies more accurately describe climate variability over larger areas than absolute temperatures do, and they give a frame of reference that allows more meaningful comparisons between locations and more accurate calculations of temperature trends.

# %%
import pandas as pd
import numpy as np

# %%
# The conversion is in another notebook
df_raw = pd.read_csv('NOAAGlobalTemp_v5.0.0_gridded_s188001_e202010_c20201108T133314.csv')

# %% [markdown]
# ### Global temp anomaly in 1880
# Some of the area of the world does not have temperature record in 1880

# %%
df_1880 = df_raw[df_raw['time'].str.contains('1880')]
df_1880 = df_1880[['lat', 'lon', 'anom']]
df_1880 = df_1880.dropna()
df_1880_mean = df_1880.groupby(['lat', 'lon']).mean().reset_index()

# %%
import plotly.express as px
fig = px.density_mapbox(df_1880_mean, lat='lat', lon='lon', z='anom', radius=15,
                        center=dict(lat=0, lon=180), zoom=0,
                        mapbox_style="stamen-terrain")
fig.show()
# Out:
# <div>
#
#
#             <div id="794b4605-c20e-4492-b35f-6085b0789fa7" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("794b4605-c20e-4492-b35f-6085b0789fa7")) {
#                     Plotly.newPlot(
#                         '794b4605-c20e-4492-b35f-6085b0789fa7',
#                         [{"coloraxis": "coloraxis", "hovertemplate": "anom=%{z}<br>lat=%{lat}<br>lon=%{lon}<extra></extra>", "lat": [-67.5, -67.5, -67.5, -67.5, -67.5, -67.5, -67.5, -67.5, -67.5, -62.5, -62.5, -62.5, -62.5, -62.5, -62.5, -62.5, -62.5, -62.5, -62.5, -62.5, -62.5, -62.5, -62.5, -62.5, -62.5, -62.5, -62.5, -62.5, -62.5, -62.5, -62.5, -62.5, -62.5, -62.5, -62.5, -62.5, -62.5, -62.5, -62.5, -57.5, -57.5, -57.5, -57.5, -57.5, -57.5, -57.5, -57.5, -57.5, -57.5, -57.5, -57.5, -57.5, -57.5, -57.5, -57.5, -57.5, -57.5, -57.5, -57.5, -57.5, -57.5, -57.5, -57.5, -57.5, -57.5, -57.5, -57.5, -57.5, -57.5, -57.5, -57.5, -57.5, -57.5, -57.5, -57.5, -57.5, -57.5, -57.5, -57.5, -57.5, -57.5, -57.5, -57.5, -57.5, -57.5, -57.5, -57.5, -57.5, -57.5, -57.5, -57.5, -57.5, -57.5, -57.5, -57.5, -57.5, -57.5, -57.5, -57.5, -52.5, -52.5, -52.5, -52.5, -52.5, -52.5, -52.5, -52.5, -52.5, -52.5, -52.5, -52.5, -52.5, -52.5, -52.5, -52.5, -52.5, -52.5, -52.5, -52.5, -52.5, -52.5, -52.5, -52.5, -52.5, -52.5, -52.5, -52.5, -52.5, -52.5, -52.5, -52.5, -52.5, -52.5, -52.5, -52.5, -52.5, -52.5, -52.5, -52.5, -52.5, -52.5, -52.5, -52.5, -52.5, -52.5, -52.5, -52.5, -52.5, -52.5, -52.5, -52.5, -52.5, -52.5, -52.5, -52.5, -52.5, -52.5, -52.5, -52.5, -52.5, -52.5, -52.5, -52.5, -52.5, -52.5, -52.5, -52.5, -52.5, -52.5, -52.5, -52.5, -47.5, -47.5, -47.5, -47.5, -47.5, -47.5, -47.5, -47.5, -47.5, -47.5, -47.5, -47.5, -47.5, -47.5, -47.5, -47.5, -47.5, -47.5, -47.5, -47.5, -47.5, -47.5, -47.5, -47.5, -47.5, -47.5, -47.5, -47.5, -47.5, -47.5, -47.5, -47.5, -47.5, -47.5, -47.5, -47.5, -47.5, -47.5, -47.5, -47.5, -47.5, -47.5, -47.5, -47.5, -47.5, -47.5, -47.5, -47.5, -47.5, -47.5, -47.5, -47.5, -47.5, -47.5, -47.5, -47.5, -47.5, -47.5, -47.5, -47.5, -47.5, -47.5, -47.5, -47.5, -47.5, -47.5, -47.5, -47.5, -47.5, -47.5, -47.5, -47.5, -42.5, -42.5, -42.5, -42.5, -42.5, -42.5, -42.5, -42.5, -42.5, -42.5, -42.5, -42.5, -42.5, -42.5, -42.5, -42.5, -42.5, -42.5, -42.5, -42.5, -42.5, -42.5, -42.5, -42.5, -42.5, -42.5, -42.5, -42.5, -42.5, -42.5, -42.5, -42.5, -42.5, -42.5, -42.5, -42.5, -42.5, -42.5, -42.5, -42.5, -42.5, -42.5, -42.5, -42.5, -42.5, -42.5, -42.5, -42.5, -42.5, -42.5, -42.5, -42.5, -42.5, -42.5, -42.5, -42.5, -42.5, -42.5, -42.5, -42.5, -42.5, -42.5, -42.5, -42.5, -42.5, -42.5, -42.5, -42.5, -42.5, -42.5, -42.5, -42.5, -37.5, -37.5, -37.5, -37.5, -37.5, -37.5, -37.5, -37.5, -37.5, -37.5, -37.5, -37.5, -37.5, -37.5, -37.5, -37.5, -37.5, -37.5, -37.5, -37.5, -37.5, -37.5, -37.5, -37.5, -37.5, -37.5, -37.5, -37.5, -37.5, -37.5, -37.5, -37.5, -37.5, -37.5, -37.5, -37.5, -37.5, -37.5, -37.5, -37.5, -37.5, -37.5, -37.5, -37.5, -37.5, -37.5, -37.5, -37.5, -37.5, -37.5, -37.5, -37.5, -37.5, -37.5, -37.5, -37.5, -37.5, -37.5, -37.5, -37.5, -37.5, -37.5, -37.5, -37.5, -37.5, -37.5, -37.5, -37.5, -37.5, -37.5, -37.5, -37.5, -32.5, -32.5, -32.5, -32.5, -32.5, -32.5, -32.5, -32.5, -32.5, -32.5, -32.5, -32.5, -32.5, -32.5, -32.5, -32.5, -32.5, -32.5, -32.5, -32.5, -32.5, -32.5, -32.5, -32.5, -32.5, -32.5, -32.5, -32.5, -32.5, -32.5, -32.5, -32.5, -32.5, -32.5, -32.5, -32.5, -32.5, -32.5, -32.5, -32.5, -32.5, -32.5, -32.5, -32.5, -32.5, -32.5, -32.5, -32.5, -32.5, -32.5, -32.5, -32.5, -32.5, -32.5, -32.5, -32.5, -32.5, -32.5, -32.5, -32.5, -32.5, -32.5, -32.5, -32.5, -32.5, -32.5, -32.5, -32.5, -32.5, -32.5, -32.5, -32.5, -27.5, -27.5, -27.5, -27.5, -27.5, -27.5, -27.5, -27.5, -27.5, -27.5, -27.5, -27.5, -27.5, -27.5, -27.5, -27.5, -27.5, -27.5, -27.5, -27.5, -27.5, -27.5, -27.5, -27.5, -27.5, -27.5, -27.5, -27.5, -27.5, -27.5, -27.5, -27.5, -27.5, -27.5, -27.5, -27.5, -27.5, -27.5, -27.5, -27.5, -27.5, -27.5, -27.5, -27.5, -27.5, -27.5, -27.5, -27.5, -27.5, -27.5, -27.5, -27.5, -27.5, -27.5, -27.5, -27.5, -27.5, -27.5, -27.5, -27.5, -27.5, -27.5, -27.5, -27.5, -27.5, -27.5, -27.5, -27.5, -27.5, -27.5, -27.5, -27.5, -22.5, -22.5, -22.5, -22.5, -22.5, -22.5, -22.5, -22.5, -22.5, -22.5, -22.5, -22.5, -22.5, -22.5, -22.5, -22.5, -22.5, -22.5, -22.5, -22.5, -22.5, -22 ...

# %% [markdown]
# ### Global temp anomaly in 2020

# %%
df_2020 = df_raw[df_raw['time'].str.contains('2020')]
df_2020 = df_2020[['lat', 'lon', 'anom']]
df_2020 = df_2020.dropna()
df_2020_mean = df_2020.groupby(['lat', 'lon']).mean().reset_index()

# %%
import plotly.express as px
fig = px.density_mapbox(df_2020_mean, lat='lat', lon='lon', z='anom', radius=15,
                        center=dict(lat=0, lon=180), zoom=0,
                        mapbox_style="stamen-terrain")
fig.show()
# Out:
# <div>
#
#
#             <div id="aa453ae0-0995-42fe-8459-d7df8b6255a0" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a
, -1.5666969363636363, -1.7442992727272726, -1.8137517333333328, -1.6217247, -1.3046118641666666, -1.0003307316666665, -0.706690945, -0.4583183675, -0.35572860358333336, -0.3626140053333333, -0.3933609318333333, -0.42621069318181815, -0.2884329290909091, -0.1796686872727273, -0.14590706363636363, -0.16554851336363638, -0.15984184481818184, -0.14208334263636363, -0.1265040509090909, -0.016376155200000013, 0.15456348366666675, 0.19102589780000004, 0.21504494059999998, 0.19108808670000002, 0.19307845777777774, 0.13332353124999996, 0.12389016500000001, 0.032034449125, -0.07490045470000002, -0.020277391299999996, 0.018660068599999993, -0.06163378020000001, -0.11722514899999999, -0.11056672079999999, -0.22983773589999998, -0.279960167, -0.22154363191666673, -0.3735558583333334, -0.40029377516666664, -0.32621430516666666, -0.3339815400000001, -0.2962712191666667, -0.2112308612, -0.11333773883333335, 0.02665190829166668, 0.15584198116666667, 0.21495501050000002, 0.25110031483333334, 0.3345953408333333, 0.2984661775, 0.22445728291666667, 0.02826850766666668, 0.06630224641666667, -0.14513339445454546, -0.33868528145454546, -0.5688356005454546, -0.625698517, -0.44577218772727284, -0.4330964944444444, -0.23152081666666668, -0.0551183635, 0.0022002599999999956, -0.1501923235, -0.26567073, -0.3637819, -0.72292851, -1.0016461875, -0.9321267258333332, -0.8993210383333334, -0.8964827324999997, -1.1046046783333332, -1.1896461733333332, -1.3765758166666666, -1.620970225, -1.833711241666667, -1.5702998000000001, -1.1451165866666666, -0.9663620125, -0.77488258, -0.5401905489166666, -0.4949012366666666, -0.5801261965000001, -0.6508551558333333, -0.6502245233333334, -0.5259401516666666, -0.43524174416666667, -0.34568646666666664, -0.3326985491666667, ...

# %% [markdown]
# ### World average temp anomaly from 1880 - 2020

# %%
df_raw[['Year', 'Month', 'Day']] = df_raw['time'].str.split('-', expand = True)

# %%
df_year_mean = df_raw[['Year', 'anom']]
df_year_mean = df_year_mean.groupby(['Year']).mean().reset_index()

# %%
import plotly.express as px

fig = px.line(df_year_mean, x="Year", y="anom", title='World average temp anomaly from 1880 - 2020')
fig.show()
# Out:
# <div>
#
#
#             <div id="b82089f5-258a-4b23-813d-6cb8fabc9de2" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("b82089f5-258a-4b23-813d-6cb8fabc9de2")) {
#                     Plotly.newPlot(
#                         'b82089f5-258a-4b23-813d-6cb8fabc9de2',
#                         [{"hovertemplate": "Year=%{x}<br>anom=%{y}<extra></extra>", "legendgroup": "", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "", "orientation": "v", "showlegend": false, "type": "scatter", "x": ["1880", "1881", "1882", "1883", "1884", "1885", "1886", "1887", "1888", "1889", "1890", "1891", "1892", "1893", "1894", "1895", "1896", "1897", "1898", "1899", "1900", "1901", "1902", "1903", "1904", "1905", "1906", "1907", "1908", "1909", "1910", "1911", "1912", "1913", "1914", "1915", "1916", "1917", "1918", "1919", "1920", "1921", "1922", "1923", "1924", "1925", "1926", "1927", "1928", "1929", "1930", "1931", "1932", "1933", "1934", "1935", "1936", "1937", "1938", "1939", "1940", "1941", "1942", "1943", "1944", "1945", "1946", "1947", "1948", "1949", "1950", "1951", "1952", "1953", "1954", "1955", "1956", "1957", "1958", "1959", "1960", "1961", "1962", "1963", "1964", "1965", "1966", "1967", "1968", "1969", "1970", "1971", "1972", "1973", "1974", "1975", "1976", "1977", "1978", "1979", "1980", "1981", "1982", "1983", "1984", "1985", "1986", "1987", "1988", "1989", "1990", "1991", "1992", "1993", "1994", "1995", "1996", "1997", "1998", "1999", "2000", "2001", "2002", "2003", "2004", "2005", "2006", "2007", "2008", "2009", "2010", "2011", "2012", "2013", "2014", "2015", "2016", "2017", "2018", "2019", "2020"], "xaxis": "x", "y":
x": ["01", "02", "03", "04", "05", "06", "07", "08", "09", "10", "11", "12"], "xaxis": "x", "y": [-0.4420179849852164, -0.46261656211186697, -0.3489525558577652, -0.3301830709597819, -0.36446249616352605, -0.5115362476416734, -0.4211044703043827, -0.38986612606798965, -0.4858729586985299, -0.6184014311984282, -0.5698223042153578, -0.38732978832382914], "yaxis": "y"}, {"hovertemplate": "Year=1882<br>Month=%{x}<br>anom=%{y}<extra></extra>", "legendgroup": "1882", "line": {"color": "#00cc96", "dash": "solid"}, "mode": "lines", "name": "1882", "showlegend": true, "type": "scattergl", "x": ["01", "02", "03", "04", "05", "06", "07", "08", "09", "10", "11", "12"], "xaxis": "x", "y": [-0.21196803791971244, -0.30505186478745583, -0.390334044993188, -0.5358313482929224, -0.47615631288078925, -0.4715815102289148, -0.431525658850946, -0.3577994097443187, -0.3631782927058588, -0.5421661592228395, -0.4621251960505927, -0.5714930465220849], "yaxis": "y"}, {"hovertemplate": "Year=1883<br>Month=%{x}<br>anom=%{y}<extra></extra>", "legendgroup": "1883", "line": {"color": "#ab63fa", "dash": "solid"}, "mode": "lines", "name": "1883", "showlegend": true, "type": "scattergl", "x": ["01", "02", "03", "04", "05", "06", "07", "08", "09", "10", "11", "12"], "xaxis": "x", "y": [-0.658777599787102, -0.7032833352101932, -0.5703918712331021, -0.5805788742579262, -0.5093633144937576, -0.31644083934582784, -0.3927168590595495, -0.40111755229850365, -0.4343418440187814, -0.4859564747965911, -0.5235195281557882, -0.44820396714351124], "yaxis": "y"}, {"hovertemplate": "Year=1884<br>Month=%{x}<br>anom=%{y}<extra></extra>", "legendgroup": "1884", "line": {"color": "#FFA15A", "dash": "solid"}, "mode": "lines", "name": "1884", "showlegend": true, "type": "scattergl", "x": ["01", "02", "03", "04", "05", "06", "07", "08", "09", "10", "11", "12"], "xaxis": "x", "y": [-0.5552516432867222, -0.5433891181139512, -0.7101623521603951, -0.6810065463775841, -0.5876445575643354, -0.5969260617124768, -0.6345294738848061, -0.6056297782998731, -0.6045191127623257, -0.5147126276566526, -0.594837062289522, -0.5648610610559185], "yaxis": "y"}, {"hovertemplate": "Year=1885<br>Month=%{x}<br>anom=%{y}<extra></extra>", "legendgroup": "1885", "line": {"color": "#19d3f3", "dash": "solid"}, "mode": "lines", "name": "1885", "showlegend": true, "type": "scattergl", "x": ["01", "02", "03", "04", "05", "06", "07", "08", "09", "10", "11", "12"], "xaxis": "x", "y": [-0.877494954994356, -0.6385417451635879, -0.625240389281309, -0.6482336843710611, -0.6580070955944904, -0.6528715173888757, -0.5453855740972509, -0.6065819436937858, -0.5808613016901844, -0.5316523162801949, -0.4771279741311887, -0.34067042145350285], "yaxis": "y"}, {"hovertemplate": "Year=1886<br>Month=%{x}<br>anom=%{y}<extra></extra>", "legendgroup": "1886", "line": {"color": "#FF6692", "dash": "solid"}, "mode": "lines", "name": "1886", "showlegend": true, "type": "scattergl", "x": ["01", "02", "03", "04", "05", "06", "07", "08", "09", "10", "11", "12"], "xaxis": "x", "y": [-0.5621133429921475, -0.7204109572759158, -0.7292892444786286, -0.5533410324249586, -0.5467014854481006, -0.5946861498443979, -0.4763771700511431,  ...

# %% [markdown]
# It looks really messy so then plot the 5 coldest and warmest years

# %%
df_each_year_2 = df_each_year.groupby(['Year']).mean().reset_index()

# %%
df_each_year_2_ascend = df_each_year_2.sort_values(by='anom', ascending=True)
warm_5_year = list(df_each_year_2_ascend['Year'])[-5:]
cold_5_year = list(df_each_year_2_ascend['Year'])[:5]

# %%
import plotly.graph_objects as go

df_warm_5 = df_each_year[df_each_year['Year'].isin(warm_5_year)]
df_cold_5 = df_each_year[df_each_year['Year'].isin(cold_5_year)]

month = ['January', 'February', 'March', 'April', 'May', 'June', 'July',
         'August', 'September', 'October', 'November', 'December']
fig = go.Figure()
for year in warm_5_year:
    df_that_year = df_warm_5[df_warm_5['Year'].str.contains(year)]
    anom = list(df_that_year['anom'])
    fig.add_trace(go.Scatter(x=month, y=anom, name='Temp anom in ' + year,
                         line=dict(color='firebrick', width=2)))
for year in cold_5_year:
    df_that_year = df_cold_5[df_cold_5['Year'].str.contains(year)]
    anom = list(df_that_year['anom'])
    fig.add_trace(go.Scatter(x=month, y=anom, name='Temp anom in ' + year,
                         line=dict(color='royalblue', width=2)))    
    
    
# Edit the layout
fig.update_layout(title='Temp anomaly in each year for the 5 warmest and coldest years',
                   xaxis_title='Month',
                   yaxis_title='Temperature Anomaly (degrees C)')

fig.show()
# Out:
# <div>
#
#
#             <div id="1db61bc6-cad8-4ce0-9168-b4b48e62f01c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("1db61bc6-cad8-4ce0-9168-b4b48e62f01c")) {
#                     Plotly.newPlot(
#                         '1db61bc6-cad8-4ce0-9168-b4b48e62f01c',
#                         [{"line": {"color": "firebrick", "width": 2}, "name": "Temp anom in 2015", "type": "scatter", "x": ["January", "February", "March", "April", "May", "June", "July", "August", "September", "October", "November", "December"], "y": [0.5361661782162271, 0.5545328457123687, 0.614968158380387, 0.48364217900284096, 0.5485096997878136, 0.5690397705971562, 0.4916209828157601, 0.5767222070346218, 0.6249978209611314, 0.7530956231898237, 0.7491624335412397, 0.8256439430934367]}, {"line": {"color": "firebrick", "width": 2}, "name": "Temp anom in 2017", "type": "scatter", "x": ["January", "February", "March", "April", "May", "June", "July", "August", "September", "October", "November", "December"], "y": [0.7322522816747528, 0.7640089210623007, 0.8526413708330834, 0.6158210832415467, 0.5438855480262823, 0.485494880006725, 0.5878631218810194, 0.6706938566902826, 0.5859529777025635, 0.6076650701128039, 0.6137079987734089, 0.6713470313638884]}, {"line": {"color": "firebrick", "width": 2}, "name": "Temp anom in 2019", "type": "scatter", "x": ["January", "February", "March", "April", "May", "June", "July", "August", "September", "October", "November", "December"], "y": [0.6005220575589411, 0.5674816590552444, 0.8644260212903897, 0.6739005193860576, 0.5749420688275817, 0.6331453098379166, 0.6524463974464128, 0.6968995470274861, 0.7257373135351615, 0.7851718267018922, 0.7153734602575768, 0.778066016804954]}, {"line": {"color": "firebrick", "width": 2}, "name": "Temp anom in 2016", "type": "scatter", "x": ["January", "February", "March", "April", "May", "June", "July", "August", "September", "October", "November", "December"], "y": [0.8691586109008046, 0.9869335664148841, 0.9751391110581962, 0.800624874322333, 0.6476389615538461, 0.610007127783065, 0.6458881254928056, 0.7689271233804381, 0.7592892414504044, 0.5953721435621302, 0.5982540108384593, 0.503930238969175]}, {"line": {"color": "firebrick", "width": 2}, "name": "Temp anom in 2020", "type": "scatter", "x": ["January", "February", "March", "April", "May", "June", "July", "August", "September", "October", "November", "December"], "y": [0.8815628042749764, 0.8947533496615574, 0.849605215004958, 0.8052080165501004, 0.6726239976946512, 0.6302786793594779, 0.6619324332752471, 0.7117578491867792, 0.7697800205152969, 0.6841031751760352]}, {"line": {"color": "royalblue", "width": 2}, "name": "Temp anom in 1909", "type": "scatter", "x": ["January", "February", "March", "April", "May", "June", "July", "August", "September", "October", "November", "December"], "y": [-1.002042657405788, -0.8692951185322964, -0.9706329498539151, -1.0029394149885547, -0.8496634813760219, -0.7815072258634583, -0.7441522867765418, -0.611578777052713, -0.6096174157236408, -0.5830336836974224, -0.559243709758133, -0.7368667408101025]}, {"line": {"color": "royalblue", "width": 2}, "name": "Temp anom in 1911", "type": "scatter", "x": ["January", "February", "March", "April", "May", "June", "July", "August", "September", "October", "November", "December"], "y": [-0.9530043877148566, -0.924059773815459, -1.0344287725570094, -0.9007953454526852, -0.8630242987687035, -0.7791895273727676, -0.760972196082561, -0.7261108801569188, -0.6554146196830769, -0.5325812774331953, -0.500824269530792, -0.5685712990106002]}, {"line": {"color": "royalblue", "width": 2}, "name": "Temp anom in 1904", "type": "scatter", "x": ["January", "February", "March", "April", "May", "June", "July", "August", "September", "October", "November", "December"], "y": [-0.9268663541393831, -0.9763499646952807, -0.9423772975169671, -0.8145327047930998, -0.7797636069236953, -0.7517216624614476, -0.8150020672268804, -0.7268739649170068, -0.7636740073894992, -0.6605279667460159, -0.3744498209177984, -0.6558795095694381]}, {"line": {"color": "royalblue", "width": 2}, "name": "Temp anom in 1908", "type": "scatter", "x": ["January", "February", "March", "April", "May", "June", "July", "August", "September", "October", "November", "December"], "y": [-0. ...
#                         {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.666666666666666
